# %% [markdown]
# # ML Training Data Generation with Parameter Sweeps
#
# This notebook demonstrates how to generate synthetic training datasets for machine learning by systematically varying model parameters.
#
# **Use cases:**
# - Training neural networks for spectroscopy analysis
# - Testing parameter recovery algorithms
# - Exploring parameter sensitivity and identifiability
# - Generating data for uncertainty quantification studies

# %%
import os
import numpy as np
import trspecfit
from trspecfit.utils.sweep import ParameterSweep, SweepDataset

# %% [markdown]
# ## 1. Set Up Model
#
# First, create your model as usual. This will be the "ground truth" model that we'll vary to generate training data.

# %%
# Create parent project
project = trspecfit.Project(path=os.getcwd())

# Create file instance with axes
file = trspecfit.File(
    parent_project=project,
    energy=np.arange(0, 20, 0.01),
    time=np.arange(-10, 100, 0.1)
)

# %%
# Load energy-resolved model
file.load_model(
    model_yaml='models_energy.yaml',
    model_info=['single_peak']
)
# Out:
# Loading model to describe energy- (and time-)dependent data: single_peak

# %%
# Add time dependence to make it 2D
file.add_time_dependence(
    model_yaml="models_time.yaml",
    model_info=['MonoExpPosIRF'],
    par_name="GLP_01_x0"
)
# Out:
# Loading model to describe time-dependence of a model parameter: GLP_01_x0 of MonoExpPosIRF model

# %%
# Examine the model structure
file.model_active.describe()
# Out:
# model name: single_peak
# function: Offset from <module 'trspecfit.functions.energy' from '/pscratch/sd/x/xchong/3RSE/931/simulation/time-resolved-spectroscopy-fit/src/trspecfit/functions/energy.py'>
# function: LinBack from <module 'trspecfit.functions.energy' from '/pscratch/sd/x/xchong/3RSE/931/simulation/time-resolved-spectroscopy-fit/src/trspecfit/functions/energy.py'>
# function: GLP from <module 'trspecfit.functions.energy' from '/pscratch/sd/x/xchong/3RSE/931/simulation/time-resolved-spectroscopy-fit/src/trspecfit/functions/energy.py'>
# all (1D flattened if applicable) lmfit.Parameters(): [sorted alphabetically]
# Name                        Value      Min      Max   Stderr     Vary     Expr Brute_Step
# GLP_01_A                       10        5       15     None     True     None     None
# GLP_01_F                        1     0.75      2.5     None     True     None     None
# GLP_01_m                      0.3        0        1     None     True     None     None
# GLP_01_x0                      10        5       15     None     True     None     None
# GLP_01_x0_expFun_01_A           5        0       15     None     True     None     None
# GLP_01_x0_expFun_01_t0          0        0        1     None    False     None     None
# GLP_01_x0_expFun_01_tau        50        1      100     None     True     None     None
# GLP_01_x0_expFun_01_y0          0        0        1     None    False     None     None
# GLP_01_x0_gaussCONV_SD          3        0       10     None     True     None     None
# LinBack_pLinear             0.004        0        1     None     True     None     None
# Offset_y0                       2        0        5     None     True     None     None

# %% [markdown]
# ## 2. Define Parameter Space
#
# Choose which parameters to vary and how. You can use:
# - **Discrete ranges**: `add_range()` for specific values
# - **Continuous distributions**: `add_uniform()`, `add_normal()`, `add_lognormal()`
#
# Strategy options:
# - **`'grid'`**: Full combinatorial - every combination (good for small spaces)
# - **`'random'`**: Independent sampling (scalable for ML)

# %% [markdown]
# ### Example 1: Small Grid Sweep
#
# Good for systematic exploration of a few parameter values.

# %%
# Define a small grid
sweep_grid = ParameterSweep(strategy='grid', seed=42)
sweep_grid.add_range('GLP_01_x0_expFun_01_A', [0.25, 1, 4])
sweep_grid.add_uniform('GLP_01_x0_expFun_01_tau', min_val=5, max_val=25, n_samples=3)

print(f"Total configurations: {sweep_grid.get_n_configs()}")
print("\nFirst 5 configurations:")
for i, config in enumerate(sweep_grid):
    if i >= 5:
        break
    print(f"  Config {i}: {config}")
# Out:
# Total configurations: 9
#
# First 5 configurations:
#   Config 0: {'GLP_01_x0_expFun_01_A': np.float64(0.25), 'GLP_01_x0_expFun_01_tau': np.float64(12.49080237694725)}
#   Config 1: {'GLP_01_x0_expFun_01_A': np.float64(0.25), 'GLP_01_x0_expFun_01_tau': np.float64(24.01428612819832)}
#   Config 2: {'GLP_01_x0_expFun_01_A': np.float64(0.25), 'GLP_01_x0_expFun_01_tau': np.float64(19.6398788362281)}
#   Config 3: {'GLP_01_x0_expFun_01_A': np.float64(1.0), 'GLP_01_x0_expFun_01_tau': np.float64(12.49080237694725)}
#   Config 4: {'GLP_01_x0_expFun_01_A': np.float64(1.0), 'GLP_01_x0_expFun_01_tau': np.float64(24.01428612819832)}

# %% [markdown]
# ### Example 2: Random Sampling (Recommended for ML)
#
# Samples parameters independently - scales to large datasets.

# %%
# Define random sampling sweep
sweep_random = ParameterSweep(strategy='random', seed=42)

# Vary peak amplitude
sweep_random.add_uniform('GLP_01_A', min_val=8, max_val=12, n_samples=100)

# Vary peak position
sweep_random.add_uniform('GLP_01_x0', min_val=8, max_val=12, n_samples=100)

# Vary dynamics amplitude
sweep_random.add_uniform('GLP_01_x0_expFun_01_A', min_val=0.5, max_val=5, n_samples=100)

# Vary decay time constant
sweep_random.add_uniform('GLP_01_x0_expFun_01_tau', min_val=10, max_val=80, n_samples=100)

print(f"Total configurations: {sweep_random.get_n_configs()}")
print("\nFirst 5 configurations:")
for i, config in enumerate(sweep_random):
    if i >= 5:
        break
    print(f"  Config {i}:")
    for k, v in config.items():
        print(f"    {k}: {v:.3f}")
# Out:
# Total configurations: 100
#
# First 5 configurations:
#   Config 0:
#     GLP_01_A: 9.498
#     GLP_01_x0: 11.803
#     GLP_01_x0_expFun_01_A: 3.794
#     GLP_01_x0_expFun_01_tau: 51.906
#   Config 1:
#     GLP_01_A: 8.624
#     GLP_01_x0: 8.624
#     GLP_01_x0_expFun_01_A: 0.761
#     GLP_01_x0_expFun_01_tau: 70.632
#   Config 2:
#     GLP_01_A: 10.404
#     GLP_01_x0: 10.832
#     GLP_01_x0_expFun_01_A: 0.593
#     GLP_01_x0_expFun_01_tau: 77.894
#   Config 3:
#     GLP_01_A: 11.330
#     GLP_01_x0: 8.849
#     GLP_01_x0_expFun_01_A: 1.318
#     GLP_01_x0_expFun_01_tau: 22.838
#   Config 4:
#     GLP_01_A: 9.217
#     GLP_01_x0: 10.099
#     GLP_01_x0_expFun_01_A: 2.444
#     GLP_01_x0_expFun_01_tau: 30.386

# %% [markdown]
# ## 3. Generate Training Data
#
# Use `simulate_parameter_sweep()` to generate datasets. This:
# 1. Iterates through parameter configurations
# 2. Updates model parameters
# 3. Generates N noisy realizations per configuration
# 4. Saves everything to HDF5 file
#
# **Memory efficiency**: Only one configuration in memory at a time!

# %%
# Create simulator
sim = trspecfit.Simulator(
    model=file.model_active,
    detection='analog',
    noise_level=0.05,
    noise_type='poisson',
    seed=42
)

# %% [markdown]
# ### Small Test Dataset (Quick)
#
# Generate a small dataset first to verify everything works.

# %%
# Use the grid sweep for quick test
sim.simulate_parameter_sweep(
    parameter_sweep=sweep_grid,
    N_realizations=3,
    filepath='test_sweep.h5',
    show_progress=True
)
# Out:
# Starting parameter sweep:
#   Total configurations: 9
#   Realizations per config: 3
#   Total datasets: 27
#   Output file: /pscratch/sd/x/xchong/3RSE/931/simulation/time-resolved-spectroscopy-fit/examples/simulator/simulated_data/test_sweep.h5
#
# Processing config 1/9: {GLP_01_x0_expFun_01_A=0.25, GLP_01_x0_expFun_01_tau=12.5}
#   ✓ Saved config 1 with 3 realizations
# Processing config 2/9: {GLP_01_x0_expFun_01_A=0.25, GLP_01_x0_expFun_01_tau=24}
#   ✓ Saved config 2 with 3 realizations
# Processing config 3/9: {GLP_01_x0_expFun_01_A=0.25, GLP_01_x0_expFun_01_tau=19.6}
#   ✓ Saved config 3 with 3 realizations
# Processing config 4/9: {GLP_01_x0_expFun_01_A=1, GLP_01_x0_expFun_01_tau=12.5}
#   ✓ Saved config 4 with 3 realizations
# Processing config 5/9: {GLP_01_x0_expFun_01_A=1, GLP_01_x0_expFun_01_tau=24}
#   ✓ Saved config 5 with 3 realizations
# Processing config 6/9: {GLP_01_x0_expFun_01_A=1, GLP_01_x0_expFun_01_tau=19.6}
#   ✓ Saved config 6 with 3 realizations
# Processing config 7/9: {GLP_01_x0_expFun_01_A=4, GLP_01_x0_expFun_01_tau=12.5}
#   ✓ Saved config 7 with 3 realizations
# Processing config 8/9: {GLP_01_x0_expFun_01_A=4, GLP_01_x0_expFun_01_tau=24}
#   ✓ Saved config 8 with 3 realizations
# Processing config 9/9: {GLP_01_x0_expFun_01_A=4, GLP_01_x0_expFun_01_tau=19.6}
#   ✓ Saved config 9 with 3 realizations
#
# ============================================================
# Parameter sweep complete!
# Generated 9 configs × 3 realizations
# Total datasets: 27
# Data saved to: /pscratch/sd/x/xchong/3RSE/931/simulation/time-resolved-spectroscopy-fit/examples/simulator/simulated_data/test_sweep.h5
# ============================================================

# %% [markdown]
# ### Large Training Dataset (Takes Time)
#
# Generate the full ML training dataset. Adjust N_realizations based on your needs:
# - **N=10-20**: Good for most ML applications
# - **N=50+**: For robust uncertainty quantification

# %%
# Generate large training dataset
# WARNING: This will take several minutes!
sim.simulate_parameter_sweep(
    parameter_sweep=sweep_random,
    N_realizations=30,
    filepath='ml_training_data.h5',
    show_progress=True
)

# Result: 100 configs × 20 realizations = 2000 training examples
# Out:
# Starting parameter sweep:
#   Total configurations: 100
#   Realizations per config: 30
#   Total datasets: 3000
#   Output file: /pscratch/sd/x/xchong/3RSE/931/simulation/time-resolved-spectroscopy-fit/examples/simulator/simulated_data/ml_training_data.h5
#
# Processing config 1/100: {GLP_01_A=9.5, GLP_01_x0=11.8, GLP_01_x0_expFun_01_A=3.79, GLP_01_x0_expFun_01_tau=51.9}
#   ✓ Saved config 1 with 30 realizations
# Processing config 2/100: {GLP_01_A=8.28, GLP_01_x0=8.17, GLP_01_x0_expFun_01_A=0.783, GLP_01_x0_expFun_01_tau=36.5}
#   ✓ Saved config 2 with 30 realizations
# Processing config 3/100: {GLP_01_A=11.1, GLP_01_x0=10.3, GLP_01_x0_expFun_01_A=1.13, GLP_01_x0_expFun_01_tau=72}
#   ✓ Saved config 3 with 30 realizations
# Processing config 4/100: {GLP_01_A=9.86, GLP_01_x0=10.9, GLP_01_x0_expFun_01_A=4.64, GLP_01_x0_expFun_01_tau=56}
#   ✓ Saved config 4 with 30 realizations
# Processing config 5/100: {GLP_01_A=11.2, GLP_01_x0=9.31, GLP_01_x0_expFun_01_A=2.35, GLP_01_x0_expFun_01_tau=28.5}
#   ✓ Saved config 5 with 30 realizations
# Processing config 6/100: {GLP_01_A=11.8, GLP_01_x0=8.5, GLP_01_x0_expFun_01_A=2.75, GLP_01_x0_expFun_01_tau=69.5}
#   ✓ Saved config 6 with 30 realizations
# Processing config 7/100: {GLP_01_A=8.73, GLP_01_x0=11.9, GLP_01_x0_expFun_01_A=2.59, GLP_01_x0_expFun_01_tau=59.4}
#   ✓ Saved config 7 with 30 realizations
# Processing config 8/100: {GLP_01_A=8.36, GLP_01_x0=11.4, GLP_01_x0_expFun_01_A=4.64, GLP_01_x0_expFun_01_tau=76.5}
#   ✓ Saved config 8 with 30 realizations
# Processing config 9/100: {GLP_01_A=10, GLP_01_x0=11.5, GLP_01_x0_expFun_01_A=1.98, GLP_01_x0_expFun_01_tau=21.6}
#   ✓ Saved config 9 with 30 realizations
# Processing config 10/100: {GLP_01_A=12, GLP_01_x0=8.53, GLP_01_x0_expFun_01_A=3.23, GLP_01_x0_expFun_01_tau=74.7}
#   ✓ Saved config 10 with 30 realizations
# Processing config 11/100: {GLP_01_A=10.4, GLP_01_x0=9.3, GLP_01_x0_expFun_01_A=2.08, GLP_01_x0_expFun_01_tau=57}
#   ✓ Saved config 11 with 30 realizations
# Processing config 12/100: {GLP_01_A=8.71, GLP_01_x0=10.8, GLP_01_x0_expFun_01_A=1.37, GLP_01_x0_expFun_01_tau=73}
#   ✓ Saved config 12 with 30 realizations
# Processing config 13/100: {GLP_01_A=11.9, GLP_01_x0=11.5, GLP_01_x0_expFun_01_A=2.34, GLP_01_x0_expFun_01_tau=59.9}
#   ✓ Saved config 13 with 30 realizations
# Processing config 14/100: {GLP_01_A=12, GLP_01_x0=9.1, GLP_01_x0_expFun_01_A=4.88, GLP_01_x0_expFun_01_tau=29.7}
#   ✓ Saved config 14 with 30 realizations
# Processing config 15/100: {GLP_01_A=9.51, GLP_01_x0=9.19, GLP_01_x0_expFun_01_A=1.41, GLP_01_x0_expFun_01_tau=66.1}
#   ✓ Saved config 15 with 30 realizations
# Processing config 16/100: {GLP_01_A=9.89, GLP_01_x0=10, GLP_01_x0_expFun_01_A=3.87, GLP_01_x0_expFun_01_tau=63.9}
#   ✓ Saved config 16 with 30 realizations
# Processing config 17/100: {GLP_01_A=8.91, GLP_01_x0=10.9, GLP_01_x0_expFun_01_A=3.24, GLP_01_x0_expFun_01_tau=77.8}
#   ✓ Saved config 17 with 30 realizations
# Processing config 18/100: {GLP_01_A=9.46, GLP_01_x0=8.55, GLP_01_x0_expFun_01_A=0.571, GLP_01_x0_expFun_01_tau=36.7}
#   ✓ Saved config 18 with 30 realizations
# Processing config 19/100: {GLP_01_A=10.2, GLP_01_x0=11, GLP_01_x0_expFun_01_A=0.742, GLP_01_x0_expFun_01_tau=14.3}
#   ✓ Saved config 19 with 30 realizations
# Processing config 20/100: {GLP_01_A=10.9, GLP_01_x0=9.51, GLP_01_x0_expFun_01_A=2.58, GLP_01_x0_expFun_01_tau=21.6}
#   ✓ Saved config 20 with 30 realizations
# Processing config 21/100: {GLP_01_A=11.5, GLP_01_x0=12, GLP_01_x0_expFun_01_A=4.61, GLP_01_x0_expFun_01_tau=38.6}
#   ✓ Saved config 21 with 30 realizations
# Processing config 22/100: {GLP_01_A=9.39, GLP_01_x0=10.4, GLP_01_x0_expFun_01_A=2.52, GLP_01_x0_expFun_01_tau=71.3}
#   ✓ Saved config 22 with 30 realizations
# Processing config 23/100: {GLP_01_A=11.9, GLP_01_x0=9.28, GLP_01_x0_expFun_01_A=0.847, GLP_01_x0_expFun_01_tau=25.1}
#   ✓ Saved config 23 with 30 realizations
# Processing config 24/100: {GLP_01_A=8.67, GLP_01_x0=8.87, GLP_01_x0_expFun_01_A=3.48, GLP_01_x0_expFun_01_tau=37.8}
#   ✓ Saved config 24 with 30 realizations
# Processing config 25/100: {GLP_01_A=10, GLP_01_x0=11.2, GLP_01_x0_expFun_01_A=5, GLP_01_x0_expFun_01_tau=37.3}
#   ✓ Saved config 25 with 30 realizations
# Processing config 26/100: {GLP_01_A=8.27, GLP_01_x0=9.11, GLP_01_x0_expFun_01_A=3.19, GLP_01_x0_expFun_01_tau=52.8}
#   ✓ Saved config 26 with 30 realizations
# Processing config 27/100: {GLP_01_A=8.43, GLP_01_x0=8.57, GLP_01_x0_expFun_01_A=1.44, GLP_01_x0_expFun_01_tau=18.8}
#   ✓ Saved config 27 with 30 realizations
# Processing config 28/100: {GLP_01_A=10.3, GLP_01_x0=11.8, GLP_01_x0_expFun_01_A=1.33, GLP_01_x0_expFun_01_tau=23.2}
#   ✓ Saved config 28 with 30 realizations
# Processing config 29/100: {GLP_01_A=11.4, GLP_01_x0=8.51, GLP_01_x0_expFun_01_A=4.94, GLP_01_x0_expFun_01_tau=70.5}
#   ✓ Saved config 29 with 30 realizations
# Processing config 30/100: {GLP_01_A=9.52, GLP_01_x0=11.3, GLP_01_x0_expFun_01_A=0.896, GLP_01_x0_expFun_01_tau=44.3}
#   ✓ Saved config 30 with 30 realizations
# Processing config 31/100: {GLP_01_A=11.3, GLP_01_x0=11.4, GLP_01_x0_expFun_01_A=0.85, GLP_01_x0_expFun_01_tau=79.9}
#   ✓ Saved config 31 with 30 realizations
# Processing config 32/100: {GLP_01_A=10.7, GLP_01_x0=9.81, GLP_01_x0_expFun_01_A=4.91, GLP_01_x0_expFun_01_tau=56.7}
#   ✓ Saved config 32 with 30 realizations
# Processing config 33/100: {GLP_01_A=8.68, GLP_01_x0=8.51, GLP_01_x0_expFun_01_A=2.81, GLP_01_x0_expFun_01_tau=75.3}
#   ✓ Saved config 33 with 30 realizations
# Processing config 34/100: {GLP_01_A=11.3, GLP_01_x0=11.3, GLP_01_x0_expFun_01_A=1.51, GLP_01_x0_expFun_01_tau=62.2}
#   ✓ Saved config 34 with 30 realizations
# Processing config 35/100: {GLP_01_A=9.75, GLP_01_x0=10.5, GLP_01_x0_expFun_01_A=1.23, GLP_01_x0_expFun_01_tau=37.9}
#   ✓ Saved config 35 with 30 realizations
# Processing config 36/100: {GLP_01_A=10.3, GLP_01_x0=11.9, GLP_01_x0_expFun_01_A=2.26, GLP_01_x0_expFun_01_tau=51.9}
#   ✓ Saved config 36 with 30 realizations
# Processing config 37/100: {GLP_01_A=10.9, GLP_01_x0=11.6, GLP_01_x0_expFun_01_A=4.42, GLP_01_x0_expFun_01_tau=43.8}
#   ✓ Saved config 37 with 30 realizations
# Processing config 38/100: {GLP_01_A=8.64, GLP_01_x0=8.91, GLP_01_x0_expFun_01_A=3.75, GLP_01_x0_expFun_01_tau=51.6}
#   ✓ Saved config 38 with 30 realizations
# Processing config 39/100: {GLP_01_A=12, GLP_01_x0=8.3, GLP_01_x0_expFun_01_A=3.3, GLP_01_x0_expFun_01_tau=33.3}
#   ✓ Saved config 39 with 30 realizations
# Processing config 40/100: {GLP_01_A=8.26, GLP_01_x0=10.8, GLP_01_x0_expFun_01_A=1.75, GLP_01_x0_expFun_01_tau=20.5}
#   ✓ Saved config 40 with 30 realizations
# Processing config 41/100: {GLP_01_A=11.8, GLP_01_x0=10.1, GLP_01_x0_expFun_01_A=0.539, GLP_01_x0_expFun_01_tau=48.4}
#   ✓ Saved config 41 with 30 realizations
# Processing config 42/100: {GLP_01_A=8.92, GLP_01_x0=8.27, GLP_01_x0_expFun_01_A=1.51, GLP_01_x0_expFun_01_tau=56.8}
#   ✓ Saved config 42 with 30 realizations
# Processing config 43/100: {GLP_01_A=10.2, GLP_01_x0=10.7, GLP_01_x0_expFun_01_A=3.14, GLP_01_x0_expFun_01_tau=78.6}
#   ✓ Saved config 43 with 30 realizations
# Processing config 44/100: {GLP_01_A=8.19, GLP_01_x0=11.1, GLP_01_x0_expFun_01_A=1.85, GLP_01_x0_expFun_01_tau=38}
#   ✓ Saved config 44 with 30 realizations
# Processing config 45/100: {GLP_01_A=11, GLP_01_x0=8.55, GLP_01_x0_expFun_01_A=2.9, GLP_01_x0_expFun_01_tau=43}
#   ✓ Saved config 45 with 30 realizations
# Processing config 46/100: {GLP_01_A=10.2, GLP_01_x0=8.99, GLP_01_x0_expFun_01_A=0.782, GLP_01_x0_expFun_01_tau=32.7}
#   ✓ Saved config 46 with 30 realizations
# Processing config 47/100: {GLP_01_A=8.9, GLP_01_x0=10.8, GLP_01_x0_expFun_01_A=2, GLP_01_x0_expFun_01_tau=75.3}
#   ✓ Saved config 47 with 30 realizations
# Processing config 48/100: {GLP_01_A=11.9, GLP_01_x0=11, GLP_01_x0_expFun_01_A=2.16, GLP_01_x0_expFun_01_tau=37.8}
#   ✓ Saved config 48 with 30 realizations
# Processing config 49/100: {GLP_01_A=10.7, GLP_01_x0=9.03, GLP_01_x0_expFun_01_A=2.16, GLP_01_x0_expFun_01_tau=28.8}
#   ✓ Saved config 49 with 30 realizations
# Processing config 50/100: {GLP_01_A=10.1, GLP_01_x0=8.41, GLP_01_x0_expFun_01_A=1.39, GLP_01_x0_expFun_01_tau=23.6}
#   ✓ Saved config 50 with 30 realizations
# Processing config 51/100: {GLP_01_A=10.6, GLP_01_x0=11.8, GLP_01_x0_expFun_01_A=4.04, GLP_01_x0_expFun_01_tau=22.7}
#   ✓ Saved config 51 with 30 realizations
# Processing config 52/100: {GLP_01_A=9.72, GLP_01_x0=8.21, GLP_01_x0_expFun_01_A=1.73, GLP_01_x0_expFun_01_tau=43.7}
#   ✓ Saved config 52 with 30 realizations
# Processing config 53/100: {GLP_01_A=8.56, GLP_01_x0=11.8, GLP_01_x0_expFun_01_A=0.689, GLP_01_x0_expFun_01_tau=32.8}
#   ✓ Saved config 53 with 30 realizations
# Processing config 54/100: {GLP_01_A=10.8, GLP_01_x0=10.8, GLP_01_x0_expFun_01_A=2.08, GLP_01_x0_expFun_01_tau=76.3}
#   ✓ Saved config 54 with 30 realizations
# Processing config 55/100: {GLP_01_A=9.36, GLP_01_x0=8.53, GLP_01_x0_expFun_01_A=1.96, GLP_01_x0_expFun_01_tau=21.3}
#   ✓ Saved config 55 with 30 realizations
# Processing config 56/100: {GLP_01_A=11.1, GLP_01_x0=9.2, GLP_01_x0_expFun_01_A=2.58, GLP_01_x0_expFun_01_tau=31.7}
#   ✓ Saved config 56 with 30 realizations
# Processing config 57/100: {GLP_01_A=10.3, GLP_01_x0=9.73, GLP_01_x0_expFun_01_A=1.48, GLP_01_x0_expFun_01_tau=17.1}
#   ✓ Saved config 57 with 30 realizations
# Processing config 58/100: {GLP_01_A=9.71, GLP_01_x0=9.69, GLP_01_x0_expFun_01_A=4.14, GLP_01_x0_expFun_01_tau=64.4}
#   ✓ Saved config 58 with 30 realizations
# Processing config 59/100: {GLP_01_A=8.03, GLP_01_x0=11.8, GLP_01_x0_expFun_01_A=3.69, GLP_01_x0_expFun_01_tau=75.5}
#   ✓ Saved config 59 with 30 realizations
# Processing config 60/100: {GLP_01_A=11.6, GLP_01_x0=11.8, GLP_01_x0_expFun_01_A=3.63, GLP_01_x0_expFun_01_tau=17.1}
#   ✓ Saved config 60 with 30 realizations
# Processing config 61/100: {GLP_01_A=11.4, GLP_01_x0=8.91, GLP_01_x0_expFun_01_A=3.56, GLP_01_x0_expFun_01_tau=64.4}
#   ✓ Saved config 61 with 30 realizations
# Processing config 62/100: {GLP_01_A=8.06, GLP_01_x0=11.6, GLP_01_x0_expFun_01_A=4.16, GLP_01_x0_expFun_01_tau=37.9}
#   ✓ Saved config 62 with 30 realizations
# Processing config 63/100: {GLP_01_A=9.28, GLP_01_x0=8.38, GLP_01_x0_expFun_01_A=3.58, GLP_01_x0_expFun_01_tau=62.1}
#   ✓ Saved config 63 with 30 realizations
# Processing config 64/100: {GLP_01_A=8.95, GLP_01_x0=10.5, GLP_01_x0_expFun_01_A=3.14, GLP_01_x0_expFun_01_tau=38.7}
#   ✓ Saved config 64 with 30 realizations
# Processing config 65/100: {GLP_01_A=8.16, GLP_01_x0=11.6, GLP_01_x0_expFun_01_A=4.7, GLP_01_x0_expFun_01_tau=54.1}
#   ✓ Saved config 65 with 30 realizations
# Processing config 66/100: {GLP_01_A=11.7, GLP_01_x0=11.6, GLP_01_x0_expFun_01_A=4.28, GLP_01_x0_expFun_01_tau=59}
#   ✓ Saved config 66 with 30 realizations
# Processing config 67/100: {GLP_01_A=11.4, GLP_01_x0=11.2, GLP_01_x0_expFun_01_A=1.45, GLP_01_x0_expFun_01_tau=72.6}
#   ✓ Saved config 67 with 30 realizations
# Processing config 68/100: {GLP_01_A=11.4, GLP_01_x0=10.4, GLP_01_x0_expFun_01_A=1.55, GLP_01_x0_expFun_01_tau=52.2}
#   ✓ Saved config 68 with 30 realizations
# Processing config 69/100: {GLP_01_A=11.2, GLP_01_x0=8.13, GLP_01_x0_expFun_01_A=2.87, GLP_01_x0_expFun_01_tau=77.4}
#   ✓ Saved config 69 with 30 realizations
# Processing config 70/100: {GLP_01_A=9.31, GLP_01_x0=8.95, GLP_01_x0_expFun_01_A=3.03, GLP_01_x0_expFun_01_tau=57.1}
#   ✓ Saved config 70 with 30 realizations
# Processing config 71/100: {GLP_01_A=11.5, GLP_01_x0=8.38, GLP_01_x0_expFun_01_A=2.44, GLP_01_x0_expFun_01_tau=66}
#   ✓ Saved config 71 with 30 realizations
# Processing config 72/100: {GLP_01_A=9.41, GLP_01_x0=10.1, GLP_01_x0_expFun_01_A=3.06, GLP_01_x0_expFun_01_tau=36.5}
#   ✓ Saved config 72 with 30 realizations
# Processing config 73/100: {GLP_01_A=8.12, GLP_01_x0=8.5, GLP_01_x0_expFun_01_A=1.99, GLP_01_x0_expFun_01_tau=50.8}
#   ✓ Saved config 73 with 30 realizations
# Processing config 74/100: {GLP_01_A=10, GLP_01_x0=11.4, GLP_01_x0_expFun_01_A=2.57, GLP_01_x0_expFun_01_tau=35.8}
#   ✓ Saved config 74 with 30 realizations
# Processing config 75/100: {GLP_01_A=11.4, GLP_01_x0=9.04, GLP_01_x0_expFun_01_A=1.72, GLP_01_x0_expFun_01_tau=27.9}
#   ✓ Saved config 75 with 30 realizations
# Processing config 76/100: {GLP_01_A=10.8, GLP_01_x0=10.5, GLP_01_x0_expFun_01_A=4.61, GLP_01_x0_expFun_01_tau=25.5}
#   ✓ Saved config 76 with 30 realizations
# Processing config 77/100: {GLP_01_A=8.4, GLP_01_x0=8.34, GLP_01_x0_expFun_01_A=2.51, GLP_01_x0_expFun_01_tau=64.5}
#   ✓ Saved config 77 with 30 realizations
# Processing config 78/100: {GLP_01_A=8.61, GLP_01_x0=8.07, GLP_01_x0_expFun_01_A=1.63, GLP_01_x0_expFun_01_tau=60.2}
#   ✓ Saved config 78 with 30 realizations
# Processing config 79/100: {GLP_01_A=8.21, GLP_01_x0=9.85, GLP_01_x0_expFun_01_A=1.99, GLP_01_x0_expFun_01_tau=32.1}
#   ✓ Saved config 79 with 30 realizations
# Processing config 80/100: {GLP_01_A=10.6, GLP_01_x0=9.71, GLP_01_x0_expFun_01_A=1.21, GLP_01_x0_expFun_01_tau=69.2}
#   ✓ Saved config 80 with 30 realizations
# Processing config 81/100: {GLP_01_A=10.6, GLP_01_x0=10.9, GLP_01_x0_expFun_01_A=1.16, GLP_01_x0_expFun_01_tau=14.8}
#   ✓ Saved config 81 with 30 realizations
# Processing config 82/100: {GLP_01_A=9.96, GLP_01_x0=9.13, GLP_01_x0_expFun_01_A=2.11, GLP_01_x0_expFun_01_tau=36.5}
#   ✓ Saved config 82 with 30 realizations
# Processing config 83/100: {GLP_01_A=10.7, GLP_01_x0=8.25, GLP_01_x0_expFun_01_A=3.4, GLP_01_x0_expFun_01_tau=32.1}
#   ✓ Saved config 83 with 30 realizations
# Processing config 84/100: {GLP_01_A=10.2, GLP_01_x0=11.9, GLP_01_x0_expFun_01_A=3.44, GLP_01_x0_expFun_01_tau=61.4}
#   ✓ Saved config 84 with 30 realizations
# Processing config 85/100: {GLP_01_A=8.61, GLP_01_x0=8.37, GLP_01_x0_expFun_01_A=2.32, GLP_01_x0_expFun_01_tau=78.1}
#   ✓ Saved config 85 with 30 realizations
# Processing config 86/100: {GLP_01_A=9.9, GLP_01_x0=9.12, GLP_01_x0_expFun_01_A=3.3, GLP_01_x0_expFun_01_tau=53.9}
#   ✓ Saved config 86 with 30 realizations
# Processing config 87/100: {GLP_01_A=8.81, GLP_01_x0=9.45, GLP_01_x0_expFun_01_A=1.65, GLP_01_x0_expFun_01_tau=61.7}
#   ✓ Saved config 87 with 30 realizations
# Processing config 88/100: {GLP_01_A=9.05, GLP_01_x0=9.78, GLP_01_x0_expFun_01_A=4.91, GLP_01_x0_expFun_01_tau=76.2}
#   ✓ Saved config 88 with 30 realizations
# Processing config 89/100: {GLP_01_A=9.15, GLP_01_x0=8.67, GLP_01_x0_expFun_01_A=3.15, GLP_01_x0_expFun_01_tau=42.8}
#   ✓ Saved config 89 with 30 realizations
# Processing config 90/100: {GLP_01_A=8.42, GLP_01_x0=10.2, GLP_01_x0_expFun_01_A=3.48, GLP_01_x0_expFun_01_tau=14.4}
#   ✓ Saved config 90 with 30 realizations
# Processing config 91/100: {GLP_01_A=11.5, GLP_01_x0=11.5, GLP_01_x0_expFun_01_A=4.95, GLP_01_x0_expFun_01_tau=79.1}
#   ✓ Saved config 91 with 30 realizations
# Processing config 92/100: {GLP_01_A=8.51, GLP_01_x0=10.3, GLP_01_x0_expFun_01_A=1.08, GLP_01_x0_expFun_01_tau=52.1}
#   ✓ Saved config 92 with 30 realizations
# Processing config 93/100: {GLP_01_A=10.8, GLP_01_x0=10.8, GLP_01_x0_expFun_01_A=0.844, GLP_01_x0_expFun_01_tau=22.7}
#   ✓ Saved config 93 with 30 realizations
# Processing config 94/100: {GLP_01_A=11.1, GLP_01_x0=10.4, GLP_01_x0_expFun_01_A=4.86, GLP_01_x0_expFun_01_tau=30.7}
#   ✓ Saved config 94 with 30 realizations
# Processing config 95/100: {GLP_01_A=11.3, GLP_01_x0=12, GLP_01_x0_expFun_01_A=1.1, GLP_01_x0_expFun_01_tau=13}
#   ✓ Saved config 95 with 30 realizations
# Processing config 96/100: {GLP_01_A=8.91, GLP_01_x0=11.8, GLP_01_x0_expFun_01_A=2.88, GLP_01_x0_expFun_01_tau=36.7}
#   ✓ Saved config 96 with 30 realizations
# Processing config 97/100: {GLP_01_A=8.95, GLP_01_x0=9, GLP_01_x0_expFun_01_A=2.78, GLP_01_x0_expFun_01_tau=28.7}
#   ✓ Saved config 97 with 30 realizations
# Processing config 98/100: {GLP_01_A=11.6, GLP_01_x0=8.68, GLP_01_x0_expFun_01_A=2.76, GLP_01_x0_expFun_01_tau=40.5}
#   ✓ Saved config 98 with 30 realizations
# Processing config 99/100: {GLP_01_A=9.51, GLP_01_x0=8.11, GLP_01_x0_expFun_01_A=3.72, GLP_01_x0_expFun_01_tau=62}
#   ✓ Saved config 99 with 30 realizations
# Processing config 100/100: {GLP_01_A=12, GLP_01_x0=8.16, GLP_01_x0_expFun_01_A=3.75, GLP_01_x0_expFun_01_tau=49.6}
#   ✓ Saved config 100 with 30 realizations
#
# ============================================================
# Parameter sweep complete!
# Generated 100 configs × 30 realizations
# Total datasets: 3000
# Data saved to: /pscratch/sd/x/xchong/3RSE/931/simulation/time-resolved-spectroscopy-fit/examples/simulator/simulated_data/ml_training_data.h5
# ============================================================

# %% [markdown]
# ## 4. Inspect Generated Data
#
# Use `SweepDataset` to examine what was generated.

# %%
# Load dataset inspector
dataset = SweepDataset('simulated_data/ml_training_data.h5')
#dataset = SweepDataset('simulated_data/test_sweep.h5')

# %%
# Print comprehensive summary
dataset.print_summary()
# Out:
# Dataset: simulated_data/ml_training_data.h5
# ============================================================
# Configurations: 100
# Realizations per config: 30
# Total datasets: 3000
#
# Data dimensions: 2D (time × energy)
# Energy points: 2000
# Time points: 1100
#
# Detection: analog
# Noise level: 0.05
# Noise type: poisson
#
# Parameter space:
#   GLP_01_A: uniform(8, 12) - 100 samples
#   GLP_01_x0: uniform(8, 12) - 100 samples
#   GLP_01_x0_expFun_01_A: uniform(0.5, 5) - 100 samples
#   GLP_01_x0_expFun_01_tau: uniform(10, 80) - 100 samples

# %%
# Get parameter summary as DataFrame
df = dataset.get_parameter_summary()
print("\nParameter configurations:")
display(df.round(3))

print("\nStatistical summary:")
display(df.describe().round(3))
# Out:
# Parameter configurations:
#             GLP_01_A  GLP_01_x0  GLP_01_x0_expFun_01_A  \
# config_idx
# 0              9.498     11.803                  3.794
# 1              8.283      8.169                  0.783
# 2             11.100     10.348                  1.135
# 3              9.857     10.903                  4.642
# 4             11.225      9.311                  2.348
# ...              ...        ...                    ...
# 95             8.907     11.820                  2.884
# 96             8.953      9.003                  2.779
# 97            11.620      8.679                  2.756
# 98             9.514      8.112                  3.721
# 99            11.994      8.164                  3.753
#
#             GLP_01_x0_expFun_01_tau
# config_idx
# 0                            51.906
# 1                            36.458
# 2                            71.967
# 3                            56.018
# 4                            28.450
# ...                             ...
# 95                           36.712
# 96                           28.713
# 97                           40.510
# 98                           61.988
# 99                           49.577
#
# [100 rows x 4 columns]
# Statistical summary:
#        GLP_01_A  GLP_01_x0  GLP_01_x0_expFun_01_A  GLP_01_x0_expFun_01_tau
# count   100.000    100.000                100.000                  100.000
# mean     10.030      9.982                  2.641                   47.762
# std       1.220      1.281                  1.261                   19.485
# min       8.026      8.067                  0.539                   12.972
# 25%       8.907      8.825                  1.541                   32.131
# 50%      10.024      9.944                  2.575                   48.977
# 75%      11.118     11.161                  3.569                   64.012
# max      12.000     11.989                  4.997                   79.877

# %%
# Visualize parameter distributions
import matplotlib.pyplot as plt

df.hist(figsize=(12, 8), bins=20)
plt.suptitle('Parameter Distributions in Training Data')
plt.tight_layout()
plt.show()

# %%
# Load a specific configuration for inspection
config = dataset.load_config(0)

print(f"Config 0 parameters:")
for k, v in config['parameters'].items():
    print(f"  {k}: {v:.3f}")

print(f"\nData shapes:")
print(f"  Clean: {config['clean'].shape}")
print(f"  Noisy realizations: {len(config['noisy'])}")
print(f"  Each realization: {config['noisy'][0].shape}")
# Out:
# Config 0 parameters:
#   GLP_01_A: 9.498
#   GLP_01_x0: 11.803
#   GLP_01_x0_expFun_01_A: 3.794
#   GLP_01_x0_expFun_01_tau: 51.906
#
# Data shapes:
#   Clean: (1100, 2000)
#   Noisy realizations: 30
#   Each realization: (1100, 2000)

# %%
# Visualize a configuration (uses simulator's built-in plotting)
print("\nVisualize configuration 0:")
print(f"  - Or use your own plotting with dataset.get_axes() for x/y axes")
print(f"  - Or (see below): Load config, set sim.data_clean/noisy, call sim.plot_comparison(dim=2)")
# Temporarily set simulator data to this config for plotting
sim.data_clean = config['clean']
sim.data_noisy = config['noisy'][0]
sim.noise = config['noisy'][0] - config['clean']
sim.plot_comparison(dim=2)
# Out:
# Visualize configuration 0:
#   - Or use your own plotting with dataset.get_axes() for x/y axes
#   - Or (see below): Load config, set sim.data_clean/noisy, call sim.plot_comparison(dim=2)

# %% [markdown]
# ## 5. Loading Data for ML Training
#
# For actual ML training, you'll typically write a custom data loader for your framework (PyTorch, TensorFlow, etc.). Here's a basic example using h5py directly:

# %%
import h5py

# Example: Load all data into memory (for small datasets)
def load_training_data(filepath, param_names):
    """
    Load parameter sweep data for ML training.
    
    Parameters
    ----------
    filepath : str
        Path to HDF5 file
    param_names : list of str
        Which parameters to extract as targets
    
    Returns
    -------
    X : list of arrays
        Input spectra (noisy realizations)
    y : list of arrays
        Target parameters for each spectrum
    """
    X = []  # Input: noisy spectra
    y = []  # Target: parameter values
    
    with h5py.File(filepath, 'r') as f:
        n_configs = f['metadata'].attrs['n_configs']
        
        for config_idx in range(n_configs):
            config_name = f'config_{config_idx:06d}'
            config_group = f['parameter_configs'][config_name]
            data_group = f['simulated_data'][config_name]
            
            # Extract target parameters
            targets = [config_group.attrs[name] for name in param_names]
            
            # Load all noisy realizations for this config
            for real_key in sorted(data_group.keys()):
                spectrum = data_group[real_key][:]
                X.append(spectrum)
                y.append(targets)
    
    return np.array(X), np.array(y)

# Example usage
X_train, y_train = load_training_data(
    'simulated_data/test_sweep.h5',
    param_names=['GLP_01_x0_expFun_01_A', 'GLP_01_x0_expFun_01_tau']
)

print(f"Training data shape: {X_train.shape}")
print(f"Target shape: {y_train.shape}")
print(f"\nFirst example target: {y_train[0]}")
# Out:
# Training data shape: (27, 1100, 2000)
# Target shape: (27, 2)
#
# First example target: [ 0.25       12.49080238]

# %% [markdown]
# ### Example: PyTorch Dataset Class
#
# For large datasets that don't fit in memory:

# %%
# Uncomment if you have PyTorch installed:
# import torch
# from torch.utils.data import Dataset, DataLoader
# 
# class SpectroscopyDataset(Dataset):
#     """PyTorch dataset for parameter sweep data."""
#     
#     def __init__(self, filepath, param_names, transform=None):
#         self.filepath = filepath
#         self.param_names = param_names
#         self.transform = transform
#         
#         # Load metadata
#         with h5py.File(filepath, 'r') as f:
#             self.n_configs = f['metadata'].attrs['n_configs']
#             self.n_realizations = f['metadata'].attrs['n_realizations_per_config']
#         
#         self.total_samples = self.n_configs * self.n_realizations
#     
#     def __len__(self):
#         return self.total_samples
#     
#     def __getitem__(self, idx):
#         # Calculate which config and realization
#         config_idx = idx // self.n_realizations
#         real_idx = idx % self.n_realizations
#         
#         with h5py.File(self.filepath, 'r') as f:
#             config_name = f'config_{config_idx:06d}'
#             config_group = f['parameter_configs'][config_name]
#             data_group = f['simulated_data'][config_name]
#             
#             # Load spectrum
#             spectrum = data_group[f'{real_idx:06d}'][:]
#             
#             # Load target parameters
#             targets = [config_group.attrs[name] for name in self.param_names]
#         
#         if self.transform:
#             spectrum = self.transform(spectrum)
#         
#         return torch.FloatTensor(spectrum), torch.FloatTensor(targets)
# 
# # Create data loader
# dataset = SpectroscopyDataset(
#     'simulated_data/test_sweep.h5',
#     param_names=['GLP_01_x0_expFun_01_A', 'GLP_01_x0_expFun_01_tau']
# )
# 
# train_loader = DataLoader(dataset, batch_size=32, shuffle=True)
# 
# # Use in training loop
# for batch_spectra, batch_targets in train_loader:
#     # ... training code ...
#     pass

print("See commented code above for PyTorch example")
# Out:
# See commented code above for PyTorch example

# %% [markdown]
# ## Tips for ML Training Data
#
# **Parameter Selection:**
# - Start with 2-3 most important parameters
# - Use realistic ranges from your experimental data
# - Include correlations if parameters are physically related
#
# **Dataset Size:**
# - Small networks: 1,000-5,000 examples often sufficient
# - Larger networks: 10,000-50,000 examples
# - More realizations per config = better uncertainty estimates
#
# **Noise Level:**
# - Match your experimental SNR
# - Can generate multiple datasets with different noise levels
# - Consider augmentation during training (add more noise)
#
# **Validation Strategy:**
# - Split by configuration, not by realization
# - Test on held-out parameter ranges
# - Validate on real experimental data when possible
